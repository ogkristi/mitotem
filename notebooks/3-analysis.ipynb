# %%
# %load_ext autoreload
# %autoreload 2
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
from config.settings import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2 as cv
import torch
from src.data.loaders import MitoSemsegDataset
from src.analysis.components import get_mito_stats
from src.visualization.analysis import show_mito_stats

dataset = MitoSemsegDataset()
img, mask = [(255*x).squeeze().to(torch.uint8).numpy() for x in dataset[98]]

stats = get_mito_stats(mask)
display(stats)

show_mito_stats(img, stats)
# Out:
#         centroid      area    perimeter                    bbox
# 0   (2206, 2471)  122551.0  1440.111822  (1987, 2247, 423, 425)
# 1   (2401, 2162)   66670.0  1030.371708  (2251, 1998, 287, 345)
# 2   (2165, 2051)   38280.0   827.435634  (2038, 1921, 248, 255)
# 3   (2122, 1882)   16665.0   517.504615  (2051, 1810, 147, 153)
# 4   (2723, 1800)   25381.0   674.984843  (2611, 1712, 211, 190)
# 5   (2281, 1759)  125781.5  2119.946513  (1995, 1466, 639, 698)
# 6   (3158, 1560)   85422.5  1160.506701  (2983, 1398, 370, 299)
# 7   (2656, 1462)   19806.5   532.943212  (2579, 1385, 159, 166)
# 8   (1622, 1601)  126257.5  2132.025597  (1439, 1316, 356, 610)
# 9   (2891, 1428)   94938.5  1291.266151  (2733, 1224, 342, 443)
# 10  (1228, 1228)   51069.0   858.548332  (1099, 1097, 257, 267)
# 11   (2541, 831)   32550.5   693.938161   (2427, 736, 225, 201)
# 12   (1833, 783)   19330.0   606.901583   (1761, 676, 157, 200)
# 13   (1763, 417)   36084.5   712.967599   (1656, 309, 218, 214)
# 14   (1150, 364)  273835.5  3142.622700     (793, 72, 853, 743)
